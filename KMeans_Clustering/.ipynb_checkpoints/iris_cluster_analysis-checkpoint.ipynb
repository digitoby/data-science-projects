# %% [markdown]
# # Species Segmentation with Cluster Analysis

# %% [markdown]
# The Iris flower dataset: https://en.wikipedia.org/wiki/Iris_flower_data_set
#
# There are 4 features: sepal length, sepal width, petal length, and petal width.

# %% [markdown]
# ## Import the relevant libraries

# %%
import os
os.environ['OMP_NUM_THREADS'] = '1'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('iris_dataset.csv')

data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Plot the data

# %%
# create a scatter plot based on two corresponding features
plt.scatter(data['sepal_length'],data['sepal_width'])
plt.xlabel('Lenght of sepal')
plt.ylabel('Width of sepal')
plt.show()

# %% [markdown]
# ## Clustering (unscaled data)

# %%
# create a variable which will contain the data for the clustering
x = data.copy()
# create a k-means object with 2 clusters
kmeans = KMeans(2)
# fit the data
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
# create a copy of data, so we can see the clusters next to the original data
clusters = data.copy()
# predict the cluster for each observation
clusters['cluster_pred']=kmeans.fit_predict(x)

# %%
plt.scatter(clusters['sepal_length'], clusters['sepal_width'], c= clusters ['cluster_pred'], cmap = 'rainbow')

# %% [markdown]
# ## Standardize the variables

# %% [markdown]
# Import and use the <i> scale </i> method from sklearn to standardize the data.

# %%
# import some preprocessing module
from sklearn import preprocessing

# scale the data for better results
x_scaled = preprocessing.scale(data)
x_scaled[:5]
# Out:
# array([[-0.90068117,  1.03205722, -1.3412724 , -1.31297673],
#        [-1.14301691, -0.1249576 , -1.3412724 , -1.31297673],
#        [-1.38535265,  0.33784833, -1.39813811, -1.31297673],
#        [-1.50652052,  0.10644536, -1.2844067 , -1.31297673],
#        [-1.02184904,  1.26346019, -1.3412724 , -1.31297673]])

# %% [markdown]
# ## Clustering (scaled data)

# %%
# create a k-means object with 2 clusters
kmeans_scaled = KMeans(2)
# fit the data
kmeans_scaled.fit(x_scaled)
# Out:
# KMeans(n_clusters=2)

# %%
# create a copy of data, so we can see the clusters next to the original data
clusters_scaled = data.copy()
# predict the cluster for each observation
clusters_scaled['cluster_pred']=kmeans_scaled.fit_predict(x_scaled)

# %%
plt.scatter(clusters_scaled['sepal_length'], clusters_scaled['sepal_width'], c= clusters_scaled ['cluster_pred'], cmap = 'rainbow')

# %% [markdown]
# The two solutions are identical. This means that the original features have very similar scales to start with.

# %% [markdown]
# ## Elbow Method

# %% [markdown]
# ### WCSS

# %%
wcss = []
# 'cl_num' keeps track the highest number of clusters we want to use the WCSS method for.
cl_num = 10
for i in range (1,cl_num):
    kmeans= KMeans(i)
    kmeans.fit(x_scaled)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)
wcss
# Out:
# [600.0000000000003,
#  223.73200573676343,
#  141.15417813388655,
#  115.68072324860235,
#  106.62643948868555,
#  97.74176248753008,
#  76.94358428209816,
#  65.489415680957,
#  57.052867685253744]

# %%
number_clusters = range(1,cl_num)
plt.plot(number_clusters, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Within-cluster Sum of Squares')
# Out:
# Text(0, 0.5, 'Within-cluster Sum of Squares')

# %% [markdown]
# ## 2 clusters

# %%
clusters_scaled
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  cluster_pred
# 0             5.1          3.5           1.4          0.2             0
# 1             4.9          3.0           1.4          0.2             0
# 2             4.7          3.2           1.3          0.2             0
# 3             4.6          3.1           1.5          0.2             0
# 4             5.0          3.6           1.4          0.2             0
# ..            ...          ...           ...          ...           ...
# 145           6.7          3.0           5.2          2.3             1
# 146           6.3          2.5           5.0          1.9             1
# 147           6.5          3.0           5.2          2.0             1
# 148           6.2          3.4           5.4          2.3             1
# 149           5.9          3.0           5.1          1.8             1
#
# [150 rows x 5 columns]

# %%
plt.scatter(data['sepal_length'],data['sepal_width'], c=clusters_scaled['cluster_pred'], cmap='rainbow')
plt.xlabel('Lenght of sepal')
plt.ylabel('Width of sepal')
plt.show()

# %% [markdown]
# ## 3 Clusters

# %%
kmeans = KMeans(3)
kmeans.fit(x_scaled)
# Out:
# KMeans(n_clusters=3)

# %%
clusters3 = data.copy()
clusters3['Cluster Pred'] = kmeans.fit_predict(x_scaled)
clusters3
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Cluster Pred
# 0             5.1          3.5           1.4          0.2             0
# 1             4.9          3.0           1.4          0.2             0
# 2             4.7          3.2           1.3          0.2             0
# 3             4.6          3.1           1.5          0.2             0
# 4             5.0          3.6           1.4          0.2             0
# ..            ...          ...           ...          ...           ...
# 145           6.7          3.0           5.2          2.3             1
# 146           6.3          2.5           5.0          1.9             2
# 147           6.5          3.0           5.2          2.0             1
# 148           6.2          3.4           5.4          2.3             1
# 149           5.9          3.0           5.1          1.8             1
#
# [150 rows x 5 columns]

# %%
plt.scatter(data['sepal_length'],data['sepal_width'], c=clusters3['Cluster Pred'], cmap='rainbow')
plt.xlabel('Lenght of sepal')
plt.ylabel('Width of sepal')
plt.show()

# %% [markdown]
# ## 5 clusters

# %%
kmeans = KMeans(5)
kmeans.fit(x_scaled)
# Out:
# KMeans(n_clusters=5)

# %%
clusters5 = data.copy()
clusters5['Cluster Pred'] = kmeans.fit_predict(x_scaled)

clusters5
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Cluster Pred
# 0             5.1          3.5           1.4          0.2             1
# 1             4.9          3.0           1.4          0.2             1
# 2             4.7          3.2           1.3          0.2             1
# 3             4.6          3.1           1.5          0.2             1
# 4             5.0          3.6           1.4          0.2             1
# ..            ...          ...           ...          ...           ...
# 145           6.7          3.0           5.2          2.3             0
# 146           6.3          2.5           5.0          1.9             2
# 147           6.5          3.0           5.2          2.0             2
# 148           6.2          3.4           5.4          2.3             0
# 149           5.9          3.0           5.1          1.8             2
#
# [150 rows x 5 columns]

# %%
plt.scatter(clusters5['sepal_length'], clusters5['sepal_width'], c=clusters5['Cluster Pred'], cmap='rainbow')
plt.show()

# %% [markdown]
# ## Compare solutions to the original iris dataset

# %%
iris_answers = pd.read_csv('iris_with_answers.csv')
iris_answers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_answers['species'] = iris_answers['species'].map({'setosa':0, 'versicolor':1, 'virginica':2})
iris_answers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
plt.scatter(iris_answers['sepal_length'], iris_answers['sepal_width'], c=iris_answers['species'], cmap='rainbow')
plt.xlabel('Sepal Width')
plt.ylabel('Sepal Length')
plt.show()
